# %% [markdown]
# # Final Project - Memprediksi nilai Net Promote Score Pealtihan Telkom CorpU
# by PYTN047ONL006-JUNDA LUTFI FALASTIAN

# %%
import pandas as pd
from sklearn import datasets
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_excel('./dataset/Nilai_LIM_1_Pelatihan.xlsx', sheet_name='LIM 1')

# %%
df
# Out:
#                               Nama Pelatihan  Objid Pelatihan Category  \
# 0           Presentasi in Territory STO TR 5         80114378      LAT
# 1           Presentasi in Territory STO TR 5         80114377      LAT
# 2     Certified Post Merger Integration Spec         80114290      LAT
# 3        Mergers & Acquisitions Professional         80114240      LAT
# 4       Testing - POJ MANAGEMENT FUNDAMENTAL         80105483      LAT
# ...                                      ...              ...      ...
# 1171                         GPMP V Batch 27         80111544      LAT
# 1172             ACCELERATOR BOARDING DAB 14         80111625      LAT
# 1173                       Assesment JT BP 2         80111675      LAT
# 1174             Social Media Ads & Analytic         80111542      LAT
# 1175                        SITAC & Litigasi         80113475      LAT
#
#                 Tipe Lokasi Pelatihan                      Provider  \
# ...

# %%
dft=df.transpose()
dft
# Out:
#                                                                0     \
# Nama Pelatihan                     Presentasi in Territory STO TR 5
# Objid Pelatihan                                            80114378
# Category                                                        LAT
# Tipe                                                            NaN
# Lokasi Pelatihan                                            Bandung
# Provider                                   Learning Area 5 Surabaya
# Academy Event                                              CONSUMER
# Location                              Online (Lokasi Masing-Masing)
# Provider Category                                          Internal
# Event Type                                                 Internal
# Status                                                 Close Budget
# Tgl Mulai                                                2020-12-30
# Tgl Selesai                                              2020-12-30
# ...

# %%
x=dft.iloc[18:25]
X=x.transpose()
X
# Out:
#      UBPP Inst UBPP Akom UBPP Sarana UBPP Penyelenggaraan UBPP Kafetaria  \
# 0        76.67         0          80                   80              0
# 1            0         0           0                    0              0
# 2        77.14         0          90                   90              0
# 3            0         0          90                   90              0
# 4          NaN         0           0                    0              0
# ...        ...       ...         ...                  ...            ...
# 1171     90.86     91.67       91.74                89.24          84.35
# 1172     91.26     94.09       91.21                92.27          93.94
# 1173         0         0           0                    0              0
# 1174     82.51        70       78.95                80.91          79.44
# 1175         0         0           0                    0              0
#
#      UBPP Materi Net Promotor Score
# 0          79.38                  0
# ...

# %%
Y=df['Y']
Y
# Out:
# 0     10024
# 1     10937
# 2     10938
# 3     12033
# 4     12062
# 5     12452
# 6     12453
# 7     12789
# 8     12989
# 9     13565
# 10    13699
# 11    14221
# 12    14698
# 13    14834
# 14    14858
# 15    15086
# 16    16294
# 17    17762
# 18    17944
# 19    18105
# 20    18192
# 21    18968
# Name: Y, dtype: int64

# %%
model = LinearRegression()
model.fit(X, Y)
# Out:
# LinearRegression()

# %%
model.score(X, Y)
# Out:
# 0.9526057954139883

# %%
model.predict([[80,155,1001]])
# Out:
# array([14664.00288908])

# %%
import pickle

# %%
pickle.dump(model,open('model_regresi.pkl','wb'))

# %%
model.predict([[10,150,1002]])
# Out:
# array([11652.87376464])
